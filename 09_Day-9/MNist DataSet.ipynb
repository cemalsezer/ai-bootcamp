# %% [markdown]
# ## MNIST Hand Written Digit Recognition

# %%
import tensorflow as tf

# %%
mnist=tf.keras.datasets.mnist
(train_images,train_labels),(test_images,test_labels)=mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(train_images[0],cmap='gray')

# %%
import random

# %%
liste=[]
for i in range(11):
    liste.append(random.randint(1,60000))

# %%
liste
# Out:
# [52231, 5068, 51429, 50728, 26219, 46821, 39072, 22663, 10630, 47388, 54323]

# %%
for i in liste:
    print(plt.imshow(train_images[5],cmap='gray'));
# Out:
# AxesImage(80,52.8;496x369.6)
# AxesImage(80,52.8;496x369.6)
# AxesImage(80,52.8;496x369.6)
# AxesImage(80,52.8;496x369.6)
# AxesImage(80,52.8;496x369.6)
# AxesImage(80,52.8;496x369.6)
# AxesImage(80,52.8;496x369.6)
# AxesImage(80,52.8;496x369.6)
# AxesImage(80,52.8;496x369.6)
# AxesImage(80,52.8;496x369.6)
# AxesImage(80,52.8;496x369.6)

# %%
train_labels[5]
# Out:
# 2

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
#Normalize/ Standardize
train_images=train_images/255.0
test_images=test_images/255.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,InputLayer,Reshape

# %%
model=Sequential()
model.add(InputLayer(input_shape=(28,28,1)))
model.add(Reshape(target_shape=(28,28,1)))
model.add(Conv2D(filters=12,kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(10))
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              optimizer='adam',metrics='accuracy')

# %%
model.fit(train_images,train_labels,validation_split=0.10,epochs=10)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 11s 6ms/step - loss: 0.3049 - accuracy: 0.9149 - val_loss: 0.1269 - val_accuracy: 0.9670
# Epoch 2/10
# 1688/1688 [==============================] - 10s 6ms/step - loss: 0.1189 - accuracy: 0.9664 - val_loss: 0.0827 - val_accuracy: 0.9775
# Epoch 3/10
# 1688/1688 [==============================] - 10s 6ms/step - loss: 0.0835 - accuracy: 0.9762 - val_loss: 0.0662 - val_accuracy: 0.9817
# Epoch 4/10
# 1688/1688 [==============================] - 10s 6ms/step - loss: 0.0688 - accuracy: 0.9797 - val_loss: 0.0663 - val_accuracy: 0.9815
# Epoch 5/10
# 1688/1688 [==============================] - 10s 6ms/step - loss: 0.0607 - accuracy: 0.9818 - val_loss: 0.0601 - val_accuracy: 0.9837
# Epoch 6/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0535 - accuracy: 0.9837 - val_loss: 0.0607 - val_accuracy: 0.9820
# Epoch 7/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0477 - accuracy: 0.9861 - val_loss: 0.0624 - val_accuracy: 0.9837
# Epoch 8/10
# 1688/1688 [==============================] - 10s 6ms/step - loss: 0.0446 - accuracy: 0.9861 - val_loss: 0.0637 - val_accuracy: 0.9828
# Epoch 9/10
# 1688/1688 [==============================] - 10s 6ms/step - loss: 0.0403 - accuracy: 0.9873 - val_loss: 0.0595 - val_accuracy: 0.9845
# Epoch 10/10
# 1688/1688 [==============================] - 10s 6ms/step - loss: 0.0366 - accuracy: 0.9889 - val_loss: 0.0569 - val_accuracy: 0.9838

# %%
_,accuracy=model.evaluate(test_images,test_labels)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 2.3026 - accuracy: 0.1608

# %%
accuracy*100
# Out:
# 16.07999950647354

# %%
model=Sequential()
model.add(InputLayer(input_shape=(28,28,1)))
model.add(Reshape(target_shape=(28,28,1)))
model.add(Conv2D(filters=12,kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(10))
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              optimizer='adam',metrics='accuracy')

# %%
model.fit(train_images,train_labels,validation_split=0.10,epochs=15)
# Out:
# Epoch 1/15
# 1688/1688 [==============================] - 9s 5ms/step - loss: 2.3234 - accuracy: 0.1820 - val_loss: 2.3026 - val_accuracy: 0.1910
# Epoch 2/15
# 1688/1688 [==============================] - 9s 5ms/step - loss: 2.3026 - accuracy: 0.1813 - val_loss: 2.3026 - val_accuracy: 0.1910
# Epoch 3/15
# 1688/1688 [==============================] - 8s 5ms/step - loss: 2.3026 - accuracy: 0.1813 - val_loss: 2.3026 - val_accuracy: 0.1910
# Epoch 4/15
# 1688/1688 [==============================] - 10s 6ms/step - loss: 2.3026 - accuracy: 0.1813 - val_loss: 2.3026 - val_accuracy: 0.1910
# Epoch 5/15
# 1688/1688 [==============================] - 9s 5ms/step - loss: 2.3026 - accuracy: 0.1813 - val_loss: 2.3026 - val_accuracy: 0.1910
# Epoch 6/15
# 1688/1688 [==============================] - 9s 5ms/step - loss: 2.3026 - accuracy: 0.1813 - val_loss: 2.3026 - val_accuracy: 0.1910
# Epoch 7/15
# 1688/1688 [==============================] - 8s 5ms/step - loss: 2.3026 - accuracy: 0.1813 - val_loss: 2.3026 - val_accuracy: 0.1910
# Epoch 8/15
# 1688/1688 [==============================] - 10s 6ms/step - loss: 2.3026 - accuracy: 0.1813 - val_loss: 2.3026 - val_accuracy: 0.1910
# Epoch 9/15
# 1688/1688 [==============================] - 10s 6ms/step - loss: 2.3026 - accuracy: 0.1813 - val_loss: 2.3026 - val_accuracy: 0.1910
# Epoch 10/15
# 1688/1688 [==============================] - 10s 6ms/step - loss: 2.3026 - accuracy: 0.1813 - val_loss: 2.3026 - val_accuracy: 0.1910
# Epoch 11/15
# 1688/1688 [==============================] - 10s 6ms/step - loss: 2.3026 - accuracy: 0.1813 - val_loss: 2.3026 - val_accuracy: 0.1910
# Epoch 12/15
# 1688/1688 [==============================] - 8s 5ms/step - loss: 2.3026 - accuracy: 0.1813 - val_loss: 2.3026 - val_accuracy: 0.1910
# Epoch 13/15
# 1688/1688 [==============================] - 10s 6ms/step - loss: 2.3026 - accuracy: 0.1813 - val_loss: 2.3026 - val_accuracy: 0.1910
# Epoch 14/15
# 1688/1688 [==============================] - 9s 5ms/step - loss: 2.3026 - accuracy: 0.1813 - val_loss: 2.3026 - val_accuracy: 0.1910
# Epoch 15/15
# 1688/1688 [==============================] - 10s 6ms/step - loss: 2.3026 - accuracy: 0.1813 - val_loss: 2.3026 - val_accuracy: 0.1910

# %%
_,accuracy=model.evaluate(test_images,test_labels)

# %%
accuracy*100

# %%
from tensorflow.keras.layers import BatchNormalization

# %%
model=Sequential()
model.add(InputLayer(input_shape=(28,28,1)))
model.add(Reshape(target_shape=(28,28,1)))
model.add(BatchNormalization())
model.add(Conv2D(filters=12,kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Flatten())
model.add(Dense(10))
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              optimizer='adam',metrics='accuracy')

# %%
history=model.fit(train_images,train_labels,batch_size = 32, epochs=5, verbose = 1, validation_data = (test_images, test_labels))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 16s 8ms/step - loss: 2.2662 - accuracy: 0.3185 - val_loss: 2.2448 - val_accuracy: 0.2825
# Epoch 2/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 2.2482 - accuracy: 0.2677 - val_loss: 2.2655 - val_accuracy: 0.2525
# Epoch 3/5
# 1875/1875 [==============================] - 12s 7ms/step - loss: 2.2723 - accuracy: 0.2435 - val_loss: 2.3026 - val_accuracy: 0.2129
# Epoch 4/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 2.3020 - accuracy: 0.2139 - val_loss: 2.3024 - val_accuracy: 0.2121
# Epoch 5/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 2.3021 - accuracy: 0.2136 - val_loss: 2.3084 - val_accuracy: 0.2258

# %%
_, accuracy=model.evaluate(test_images, test_labels)
print("Accuracy = %2f" % (accuracy*100))
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 2.3084 - accuracy: 0.2258
# Accuracy = 22.579999

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()

plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()

# %%
model=Sequential()
model.add(Conv2D(32, (3,3), activation = "relu", input_shape=(28,28,1)))
model.add(Conv2D(64, (3,3), activation = "relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(100, activation="relu"))
model.add(Dense(10, activation="softmax"))
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              optimizer='adam',metrics='accuracy')

# %%
history=model.fit(train_images,train_labels,batch_size = 32, epochs=5, verbose = 1, validation_data = (test_images, test_labels))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 76s 40ms/step - loss: 0.1172 - accuracy: 0.9644 - val_loss: 0.0451 - val_accuracy: 0.9857
# Epoch 2/5
# 1875/1875 [==============================] - 72s 38ms/step - loss: 0.0382 - accuracy: 0.9879 - val_loss: 0.0371 - val_accuracy: 0.9885
# Epoch 3/5
# 1875/1875 [==============================] - 72s 38ms/step - loss: 0.0232 - accuracy: 0.9929 - val_loss: 0.0549 - val_accuracy: 0.9843
# Epoch 4/5
# 1875/1875 [==============================] - 70s 37ms/step - loss: 0.0159 - accuracy: 0.9951 - val_loss: 0.0401 - val_accuracy: 0.9880
# Epoch 5/5
# 1875/1875 [==============================] - 70s 37ms/step - loss: 0.0122 - accuracy: 0.9959 - val_loss: 0.0438 - val_accuracy: 0.9872

# %%
_, accuracy=model.evaluate(test_images, test_labels)
print("Accuracy = %2f" % (accuracy*100))
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0438 - accuracy: 0.9872
# Accuracy = 98.720002

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()

plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()
