# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('monthly_milk_production.csv',index_col='Date',parse_dates=True)
df.index.freq='MS'

# %%
df.plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in d:\anaconda\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.17 in d:\anaconda\lib\site-packages (from statsmodels) (1.21.5)
# Requirement already satisfied: scipy>=1.3 in d:\anaconda\lib\site-packages (from statsmodels) (1.9.1)
# Requirement already satisfied: pandas>=0.25 in d:\anaconda\lib\site-packages (from statsmodels) (1.4.4)
# Requirement already satisfied: patsy>=0.5.2 in d:\anaconda\lib\site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in d:\anaconda\lib\site-packages (from statsmodels) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda\lib\site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas>=0.25->statsmodels) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\anaconda\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
results=seasonal_decompose(df['Production'])
results.plot();

# %%
len(df)
# Out:
# 168

# %%
train=df.iloc[:156]
test=df.iloc[156:]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
df.head(),df.tail()
# Out:
# (            Production
#  Date
#  1962-01-01         589
#  1962-02-01         561
#  1962-03-01         640
#  1962-04-01         656
#  1962-05-01         727,
#              Production
#  Date
#  1975-08-01         858
#  1975-09-01         817
#  1975-10-01         827
#  1975-11-01         797
#  1975-12-01         843)

# %%
scaler.fit(train)
scaled_train=scaler.transform(train)
scaled_test=scaler.transform(test)

# %%
scaled_train[:10]
# Out:
# array([[0.08653846],
#        [0.01923077],
#        [0.20913462],
#        [0.24759615],
#        [0.41826923],
#        [0.34615385],
#        [0.20913462],
#        [0.11057692],
#        [0.03605769],
#        [0.05769231]])

# %%
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
n_input=3
n_features=1
generator=TimeseriesGenerator(scaled_train,scaled_train,length=n_input,batch_size=1)

# %%
X,y=generator[0]
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n{y}')
# Out:
# Given the Array:
# [0.08653846 0.01923077 0.20913462]
# Predict this y:
# [[0.24759615]]

# %%
X.shape
# Out:
# (1, 3, 1)

# %%
n_input=12
generator=TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(100, activation='relu', input_shape=(n_input, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100)               40800
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(generator,epochs=50)
# Out:
# Epoch 1/50
# 144/144 [==============================] - 2s 6ms/step - loss: 0.0389
# Epoch 2/50
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0222
# Epoch 3/50
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0214
# Epoch 4/50
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0150
# Epoch 5/50
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0120
# Epoch 6/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0082
# Epoch 7/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0076
# Epoch 8/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0072
# Epoch 9/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0062
# Epoch 10/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0044
# Epoch 11/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0050
# Epoch 12/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0059
# Epoch 13/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0047
# Epoch 14/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0044
# Epoch 15/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0045
# Epoch 16/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0039
# Epoch 17/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0037
# Epoch 18/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0035
# Epoch 19/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0038
# Epoch 20/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0040
# Epoch 21/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0044
# Epoch 22/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0042
# Epoch 23/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0033
# Epoch 24/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0029
# Epoch 25/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0030
# Epoch 26/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0036
# Epoch 27/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0047
# Epoch 28/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0032
# Epoch 29/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0039
# Epoch 30/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0034
# Epoch 31/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0036
# Epoch 32/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0027
# Epoch 33/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0030
# Epoch 34/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0031
# Epoch 35/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0023
# Epoch 36/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0032
# Epoch 37/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0028
# Epoch 38/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0028
# Epoch 39/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0031
# Epoch 40/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0030
# Epoch 41/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0029
# Epoch 42/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0026
# Epoch 43/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0030
# Epoch 44/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0027
# Epoch 45/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0025
# Epoch 46/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0027
# Epoch 47/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0027
# Epoch 48/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0023
# Epoch 49/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0024
# Epoch 50/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0019

# %%
loss_per_epoch=model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
last_train_batch=scaled_train[-12:]

# %%
last_train_batch=last_train_batch.reshape((1,n_input, n_features))

# %%
model.predict(last_train_batch)
# Out:
# 1/1 [==============================] - 0s 175ms/step
# array([[0.6564367]], dtype=float32)

# %%
scaled_test[0]
# Out:
# array([0.67548077])

# %%
test_predictions=[]

first_eval_batch=scaled_train[-n_input:]
current_batch=first_eval_batch.reshape((1,n_input,n_features))

for i in range(len(test)):
    
    current_pred=model.predict(current_batch)[0]
    
    test_predictions.append(current_pred)
    
    current_batch=np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step

# %%
test_predictions
# Out:
# [array([0.6564367], dtype=float32),
#  array([0.6244114], dtype=float32),
#  array([0.81100714], dtype=float32),
#  array([0.8814793], dtype=float32),
#  array([1.0035977], dtype=float32),
#  array([0.97825533], dtype=float32),
#  array([0.8967538], dtype=float32),
#  array([0.7892182], dtype=float32),
#  array([0.68363845], dtype=float32),
#  array([0.6517379], dtype=float32),
#  array([0.6026467], dtype=float32),
#  array([0.6416513], dtype=float32)]

# %%
test.head()
# Out:
#             Production
# Date
# 1975-01-01         834
# 1975-02-01         782
# 1975-03-01         892
# 1975-04-01         903
# 1975-05-01         966

# %%
true_predictions=scaler.inverse_transform(test_predictions)

# %%
test['Predictions']=true_predictions
# Out:
# C:\Users\cemal\AppData\Local\Temp\ipykernel_9684\2664784394.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions']=true_predictions

# %%
test.plot(figsize=(14,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse=sqrt(mean_squared_error(test['Production'],test['Predictions']))
print(rmse)
# Out:
# 18.896922665507386
